# %%
import pydpmd as dp
from pydpmd.plot import draw_particles_frame
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
from pydpmd.data import load
import numpy as np

# %%
os.listdir()
# Out:
# ['run.py',
#  '__pycache__',
#  'run_disk.py',
#  'analyze.ipynb',
#  'system_building_resources.py']

# %%
data = load('/home/mmccraw/dev/data/10-06-25/jamming/disk/jamming_0/', location=["final"])

draw_particles_frame(None, plt.gca(), data, 0, True, 'particle', 'viridis', 'final')

data.final.packing_fraction, data.final.pe_total
# Out:
# (array([0.83939844]), array([9.99973346e-14]))

# %%
os.listdir('/home/mmccraw/dev/data/10-06-25/jamming/3-1.00/jamming_0/')
# Out:
# ['meta.h5', 'trajectory.h5']

# %%
data = load('/home/mmccraw/dev/data/10-06-25/jamming/3-1.00/jamming_0/', location=["final"])

draw_particles_frame(None, plt.gca(), data, 0, True, 'vertex', 'viridis', 'final')

data.final.packing_fraction, data.final.pe_total
# Out:
# (array([0.80863582]), array([9.9995863e-14]))
